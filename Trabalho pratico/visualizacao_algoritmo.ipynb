# %% [markdown]
# # Visualização das Estatísticas do Grafo
# Este notebook executa o código presente no arquivo `teste_uso.py`, que realiza a leitura de dados de um arquivo `.dat` e calcula diversas estatísticas do grafo.

# %%
import importlib.util

# Caminho para o script com a lógica do grafo
script_path = "teste_uso.py"

# Carrega o módulo dinamicamente
spec = importlib.util.spec_from_file_location("estatisticas_grafo", script_path)
estatisticas_grafo = importlib.util.module_from_spec(spec)
spec.loader.exec_module(estatisticas_grafo)
# Out:
# === DADOS GERAIS ===
# Name: CBMix12
# Optimal value: 3138
# #Vehicles: -1
# Capacity: 1811
# Depot Node: 21
# #Nodes: 38
# #Edges: 0
# #Arcs: 71
# #Required N: 1
# #Required E: 0
# #Required A: 52
#
# === REQUIRED NODES ===
# {'node': 'N24', 'demand': 132, 'service_cost': 132}
#
# === REQUIRED EDGES ===
#
# === NON-REQUIRED EDGES ===
#
# === REQUIRED ARCS ===
# {'arc': 'A1', 'from': 2, 'to': 3, 'traversal_cost': 41, 'demand': 318, 'service_cost': 359}
# {'arc': 'A2', 'from': 4, 'to': 5, 'traversal_cost': 36, 'demand': 268, 'service_cost': 304}
# {'arc': 'A3', 'from': 5, 'to': 11, 'traversal_cost': 37, 'demand': 300, 'service_cost': 337}
# {'arc': 'A4', 'from': 6, 'to': 1, 'traversal_cost': 41, 'demand': 135, 'service_cost': 176}
# {'arc': 'A5', 'from': 6, 'to': 12, 'traversal_cost': 17, 'demand': 310, 'service_cost': 327}
# {'arc': 'A6', 'from': 7, 'to': 6, 'traversal_cost': 37, 'demand': 76, 'service_cost': 113}
# ...

# %% [markdown]
# ## Saída do script
# Abaixo está a execução do script `teste_uso.py`, com a leitura do arquivo `.dat` e impressão das estatísticas:

# %%
# A execução já ocorre no momento da importação
# O script imprime automaticamente os resultados ao ser importado
